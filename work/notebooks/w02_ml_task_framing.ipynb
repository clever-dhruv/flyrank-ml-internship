# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/clever-dhruv/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("""Lane: Content Refresh Prediction

ML Task Type: Classification

The objective is to classify whether a webpage is likely to require a content refresh based on historical search-performance metrics. Each webpage is assigned to a class indicating whether it should be prioritized for updating.""")
# Out:
# Lane: Content Refresh Prediction
#
# ML Task Type: Classification
#
# The objective is to classify whether a webpage is likely to require a content refresh based on historical search-performance metrics. Each webpage is assigned to a class indicating whether it should be prioritized for updating.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("""The target (proxy) is whether a webpage is showing signs of declining performance.

Example target column:

1 = Page needs a content refresh.
0 = Page does not currently require a refresh.

The starter dataset uses trend-related information as a proxy for this decision.""")
# Out:
# The target (proxy) is whether a webpage is showing signs of declining performance.
#
# Example target column:
#
# 1 = Page needs a content refresh.
# 0 = Page does not currently require a refresh.
#
# The starter dataset uses trend-related information as a proxy for this decision.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("""The primary success metric is Precision@50, because the content team can only refresh a limited number of pages at a time. A higher Precision@50 means more of the top recommended pages genuinely need attention.

Additional evaluation metrics may include:

Precision
Recall
F1 Score""")
# Out:
# The primary success metric is Precision@50, because the content team can only refresh a limited number of pages at a time. A higher Precision@50 means more of the top recommended pages genuinely need attention.
#
# Additional evaluation metrics may include:
#
# Precision
# Recall
# F1 Score

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("""The unit of analysis is one webpage.

Each row in the dataset represents one webpage with measurements such as:

Clicks
Impressions
CTR
Average Position
Trend Direction
Content Age

Code cell:

import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(df.head())

print("Rows:", len(df))
print("Columns:", len(df.columns))

This demonstrates that one row corresponds to one webpage. """)
# Out:
# The unit of analysis is one webpage.
#
# Each row in the dataset represents one webpage with measurements such as:
#
# Clicks
# Impressions
# CTR
# Average Position
# Trend Direction
# Content Age
#
# Code cell:
#
# import pandas as pd
#
# df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
#
# print(df.head())
#
# print("Rows:", len(df))
# print("Columns:", len(df.columns))
#
# This demonstrates that one row corresponds to one webpage.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("""A fixed rule might recommend refreshing every page with low CTR or declining impressions. However, search performance depends on many interacting factors, including clicks, impressions, ranking position, content age, and traffic trends.

Machine learning can learn relationships between multiple features simultaneously and prioritize pages more accurately than a simple threshold-based rule. It can also adapt to patterns that would be difficult to capture manually.""")
# Out:
# A fixed rule might recommend refreshing every page with low CTR or declining impressions. However, search performance depends on many interacting factors, including clicks, impressions, ranking position, content age, and traffic trends.
#
# Machine learning can learn relationships between multiple features simultaneously and prioritize pages more accurately than a simple threshold-based rule. It can also adapt to patterns that would be difficult to capture manually.

# %% [markdown]
#  ML task type identified (Classification).
#  Target/proxy defined.
#  Success metric identified (Precision@50).
#  Unit of analysis demonstrated using the dataset.
#  Explained why machine learning is more suitable than a fixed rule.
# Connected the model output to a real-world content refresh decision.
